# %% [markdown]
# # Non Tidal [Good]

# %%
import mikeio
import pandas as pd
import os
import glob
from mikeio.eum import EUMType, EUMUnit, ItemInfo

# Output folder path (Just the folder path)
output_folder_path = r'G:\MJI\Non Tidal (172 nos.)\Output\Good\Daily_Avg'


for file in glob.glob(r'G:\MJI\Non Tidal (172 nos.)\Output\Good\Daily_Avg\*.xlsx'):

    # Splitting the path by seperator
    path_list = file.split(os.sep)  

    # File absolute path with file name and extension as xlsx
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Date'], format = "%d/%m/%Y")

    # Setting 'Date' column as dataframe index
    df.set_index(df['Date'], inplace=True)
    v_df = df['Modified']

    # Output file path and name with extension
    file_path = os.path.join(output_folder_path, '{}.dfs0'.format(path_list[-1][:-5]))

    # Defining dfs0 item with item type
    item = [ItemInfo('Modified', EUMType.Water_Level, EUMUnit.meter)]

    # Saving the dfs0 file
    v_df.to_dfs0(file_path,items=item,title='{}'.format(path_list[-1][:-18]))
    
    print(path_list[-1][:-18])

# %%
len('_Fortnightly_Avg.xlsx')
# Out:
# 21

# %%
import mikeio
import pandas as pd
import os
import glob
from mikeio.eum import EUMType, EUMUnit, ItemInfo

# Output folder path (Just the folder path)
output_folder_path = r'G:\MJI\Non Tidal (172 nos.)\Output\Good\Fortnightly_Avg'


for file in glob.glob(r'G:\MJI\Non Tidal (172 nos.)\Output\Good\Fortnightly_Avg\*.xlsx'):

    # Splitting the path by seperator
    path_list = file.split(os.sep)  

    # File absolute path with file name and extension as xlsx
    df = pd.read_excel(file)
    df['Date/Time'] = pd.to_datetime(df['Date/Time'], format = "%Y/%m/%d")

    # Setting 'Date' column as dataframe index
    df.set_index(df['Date/Time'], inplace=True)
    v_df = df['Modified']

    # Output file path and name with extension
    file_path = os.path.join(output_folder_path, '{}.dfs0'.format(path_list[-1][:-5]))

    # Defining dfs0 item with item type
    item = [ItemInfo('Modified', EUMType.Water_Level, EUMUnit.meter)]

    # Saving the dfs0 file
    v_df.to_dfs0(file_path,items=item,title='{}'.format(path_list[-1][:-21]))
    
    print(path_list[-1][:-21])
# Out:
# SW10 (Simulbari)
# SW101.5 (Kamarkhali_Gondhakhali)
# SW11 (Khanpur)
# SW11A (Shariakandi)
# SW132.2 (Phulbari)
# SW132.5 (Joypurhat)
# SW133 (Naogaon)
# SW134 (Jukerchar)
# SW135A (Juricont_Silghat)
# SW137A (Taraghat)
# SW14 (Mirzapur_Bangshi)
# SW142.1 (Bhusirbandar)
# SW147 (Atrai Rly. Bridge)
# SW147.5 (Singra)
# SW148 (Chanchkair)
# SW149 (Astamanisha)
# SW151 (Baghabari)
# SW155 (Mohimaganj Rly. Crossing)
# SW15J (Mathurpara_Milanpur)
# SW169 (Mazurdia)
# SW172.5 (Amalshid)
# SW173 (Sheola)
# SW174 (Fenchuganj)
# SW175.5 (Sherpur)
# SW181 (Gunabati Rly. Bridge)
# SW192 (Motiganj)
# SW201 (Monu Rly. Bridge)
# SW202 (Moulovi Bazar)
# SW203 (Lama)
# SW205 (Kazipur)
# SW206 (Hatboalia)
# SW207 (Chuadanga)
# SW208 (Darsana)
# SW211.5 (Chapai Nawabganj)
# SW216 (Magura)
# SW216A (Magura Diversion)
# SW223 (Goalkanda)
# SW232 (Phulbari_Outfall)
# SW233 (Protappur_Piyanganj)
# SW236 (Dinajpur_Pulhat)
# SW238 (Rohanpur)
# SW247 (Bandarban)
# SW251 (Sarighat)
# SW252 (Gowainghat)
# SW252.1 (Salutikar)
# SW261 (Nawhata)
# SW263.1 (Kalmakanda)
# SW265 (Jaldhup)
# SW266 (Kanairghat)
# SW267 (Sylhet)
# SW268 (Chhatak)
# SW269 (Sunamganj)
# SW269.5 (Dirai_on Kalni)
# SW280 (Sutang Rly. Bridge)
# SW291.5L (Doani)
# SW291.5R (Dalia)
# SW294 (Kaunia)
# SW294.5 (Haripur)
# SW301 (Kalikoir)
# SW310 (Netrokona)
# SW311.4 (Chamraghat)
# SW312 (Talora Rly. Crossing)
# SW325 (Sonaimukhi)
# SW326 (Lubachara)
# SW337 (Urargaon)
# SW343.5 (Bhuyanpur_DS)
# SW345 (Durlavpur)
# SW35.5 (Sarchapur_Mymensingh)
# SW36 (Jaria_Jhanjail)
# SW36.1 (Mohanganj)
# SW45 (Noonkhawa)
# SW45.5 (Chilmari)
# SW46 (Kamarjani)
# SW46.7L (Kholabarichar)
# SW46.9L (Bahadurabad Transit)
# SW46.9R (Fulchari Transit)
# SW48 (Jaganathganj)
# SW49 (Sirajganj)
# SW49A (Kazipur)
# SW50.3 (Mathura)
# SW50.6 (Aricha)
# SW62 (Badarganj)
# SW64 (Shibganj)
# SW65 (Bogra)
# SW72B (Sukbebpur)
# SW76 (Taluk-Simulbari)
# SW77 (Kurigram)
# SW81 (Pateswari)
# SW82 (Jotebazar Offtake)
# SW83 (Bagmara)
# SW83.1 (Naldanga Rly. Crossing)
# SW84.1 (Kaliachari)
# SW88 (Rajshahi)
# SW88A (Panka)
# SW89 (Sardah)
# SW9.5 (Trimohini)
# SW90 (Hardinge Bridge)
# SW91 (Talbaria)
# SW91.1 (Sengram)
# SW91.2 (Mohendrapur)
# SW91.9L (Baruria Transit)
# SW91.9R (Goalundo Transit)
# SW96.5 (Mirjapur)
# SW97 (Gaibandha)
# SW99 (Gorai Railway Bridge)

# %%
import mikeio
import pandas as pd
import os
import glob
from mikeio.eum import EUMType, EUMUnit, ItemInfo

# Output folder path (Just the folder path)
output_folder_path = r'G:\MJI\Non Tidal (172 nos.)\Output\Good\Fortnightly_Median_Day_Avg'


for file in glob.glob(r'G:\MJI\Non Tidal (172 nos.)\Output\Good\Fortnightly_Median_Day_Avg\*.xlsx'):

    # Splitting the path by seperator
    path_list = file.split(os.sep)  

    # File absolute path with file name and extension as xlsx
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Date'], format = "%Y/%m/%d")

    # Setting 'Date' column as dataframe index
    df.set_index(df['Date'], inplace=True)
    v_df = df['Modified']

    # Output file path and name with extension
    file_path = os.path.join(output_folder_path, '{}.dfs0'.format(path_list[-1][:-5]))

    # Defining dfs0 item with item type
    item = [ItemInfo('Modified', EUMType.Water_Level, EUMUnit.meter)]

    # Saving the dfs0 file
    v_df.to_dfs0(file_path,items=item,title='{}'.format(path_list[-1][:-32]))
    
    print(path_list[-1][:-32])
# Out:
# SW10 (Simulbari)
# SW101.5 (Kamarkhali_Gondhakhali)
# SW11 (Khanpur)
# SW11A (Shariakandi)
# SW132.2 (Phulbari)
# SW132.5 (Joypurhat)
# SW133 (Naogaon)
# SW134 (Jukerchar)
# SW135A (Juricont_Silghat)
# SW137A (Taraghat)
# SW14 (Mirzapur_Bangshi)
# SW142.1 (Bhusirbandar)
# SW147 (Atrai Rly. Bridge)
# SW147.5 (Singra)
# SW148 (Chanchkair)
# SW149 (Astamanisha)
# SW151 (Baghabari)
# SW155 (Mohimaganj Rly. Crossing)
# SW15J (Mathurpara_Milanpur)
# SW169 (Mazurdia)
# SW172.5 (Amalshid)
# SW173 (Sheola)
# SW174 (Fenchuganj)
# SW175.5 (Sherpur)
# SW181 (Gunabati Rly. Bridge)
# SW192 (Motiganj)
# SW201 (Monu Rly. Bridge)
# SW202 (Moulovi Bazar)
# SW203 (Lama)
# SW205 (Kazipur)
# SW206 (Hatboalia)
# SW207 (Chuadanga)
# SW208 (Darsana)
# SW211.5 (Chapai Nawabganj)
# SW216 (Magura)
# SW216A (Magura Diversion)
# SW223 (Goalkanda)
# SW232 (Phulbari_Outfall)
# SW233 (Protappur_Piyanganj)
# SW236 (Dinajpur_Pulhat)
# SW238 (Rohanpur)
# SW247 (Bandarban)
# SW251 (Sarighat)
# SW252 (Gowainghat)
# SW252.1 (Salutikar)
# SW261 (Nawhata)
# SW263.1 (Kalmakanda)
# SW265 (Jaldhup)
# SW266 (Kanairghat)
# SW267 (Sylhet)
# SW268 (Chhatak)
# SW269 (Sunamganj)
# SW269.5 (Dirai_on Kalni)
# SW280 (Sutang Rly. Bridge)
# SW291.5L (Doani)
# SW291.5R (Dalia)
# SW294 (Kaunia)
# SW294.5 (Haripur)
# SW301 (Kalikoir)
# SW310 (Netrokona)
# SW311.4 (Chamraghat)
# SW312 (Talora Rly. Crossing)
# SW325 (Sonaimukhi)
# SW326 (Lubachara)
# SW337 (Urargaon)
# SW343.5 (Bhuyanpur_DS)
# SW345 (Durlavpur)
# SW35.5 (Sarchapur_Mymensingh)
# SW36 (Jaria_Jhanjail)
# SW36.1 (Mohanganj)
# SW45 (Noonkhawa)
# SW45.5 (Chilmari)
# SW46 (Kamarjani)
# SW46.7L (Kholabarichar)
# SW46.9L (Bahadurabad Transit)
# SW46.9R (Fulchari Transit)
# SW48 (Jaganathganj)
# SW49 (Sirajganj)
# SW49A (Kazipur)
# SW50.3 (Mathura)
# SW50.6 (Aricha)
# SW62 (Badarganj)
# SW64 (Shibganj)
# SW65 (Bogra)
# SW72B (Sukbebpur)
# SW76 (Taluk-Simulbari)
# SW77 (Kurigram)
# SW81 (Pateswari)
# SW82 (Jotebazar Offtake)
# SW83 (Bagmara)
# SW83.1 (Naldanga Rly. Crossing)
# SW84.1 (Kaliachari)
# SW88 (Rajshahi)
# SW88A (Panka)
# SW89 (Sardah)
# SW9.5 (Trimohini)
# SW90 (Hardinge Bridge)
# SW91 (Talbaria)
# SW91.1 (Sengram)
# SW91.2 (Mohendrapur)
# SW91.9L (Baruria Transit)
# SW91.9R (Goalundo Transit)
# SW96.5 (Mirjapur)
# SW97 (Gaibandha)
# SW99 (Gorai Railway Bridge)

# %%
len('_Fortnightly_Median_Day_Avg.xlsx')
# Out:
# 32

# %% [markdown]
# # Non Tidal [Problem (Solved)]

# %%
import mikeio
import pandas as pd
import os
import glob
from mikeio.eum import EUMType, EUMUnit, ItemInfo

# Output folder path (Just the folder path)
output_folder_path = r'G:\MJI\Non Tidal (172 nos.)\Output\Problem (Solved)\Daily_Avg'


for file in glob.glob(r'G:\MJI\Non Tidal (172 nos.)\Output\Problem (Solved)\Daily_Avg\*.xlsx'):

    # Splitting the path by seperator
    path_list = file.split(os.sep)  

    # File absolute path with file name and extension as xlsx
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Date'], format = "%d/%m/%Y")

    # Setting 'Date' column as dataframe index
    df.set_index(df['Date'], inplace=True)
    v_df = df['Modified']

    # Output file path and name with extension
    file_path = os.path.join(output_folder_path, '{}.dfs0'.format(path_list[-1][:-5]))

    # Defining dfs0 item with item type
    item = [ItemInfo('Modified', EUMType.Water_Level, EUMUnit.meter)]

    # Saving the dfs0 file
    v_df.to_dfs0(file_path,items=item,title='{}'.format(path_list[-1][:-18]))
    
    print(path_list[-1][:-18])
# Out:
# SW101 (Kamarkhali Transit)
# SW109 (Bibir Bazar)
# SW11.5 (Nalkasengati)
# SW110 (Cumilla)
# SW113 (Kangsanagar)
# SW114 (Jibanpur_Gumti)
# SW117 (Narayanhat)
# SW119.1 (Panchpukuria)
# SW124 (Thandachari)
# SW131.5 (Laurergarh Saktiarkhola)
# SW138 (Sofiabad)
# SW139 (Bardeswari)
# SW140 (Panchgarh)
# SW141 (Debiganj)
# SW142 (Khansama)
# SW144 (Chak Hariharpur)
# SW145 (Mohadebpur)
# SW149.1 (Gumani Rly. Bridge)
# SW150 (Dohakolaanga)
# SW156A (Kundal)
# SW157 (Ballah)
# SW158 (Chunarghat)
# SW158.1 (Shaistaganj)
# SW159 (Habiganj)
# SW161 (Tahirpur)
# SW205A (Insafnagar)
# SW212 (Parshuram)
# SW225 (Jamalpur)
# SW227 (Offtake of Suti)
# SW228.5 (Mymensingh)
# SW233A (Jaflong_Spill)
# SW235A (Prannagar)
# SW262 (Bijoypur)
# SW263 (Durgapur)
# SW282 (Bhitagarh)
# SW285 (Thakurgaon)
# SW287 (Kodalkatigaon)
# SW293 (Kaliganj)
# SW305.5 (Ghoramaraghat)
# SW314 (Ghosegaon)
# SW333 (Muslimpur)
# SW334 (Mirar Bazar)
# SW336 (Bujruk)
# SW338 (Cansart)
# SW338.5 (Ramkrishnapur)
# SW34 (Nakuagaon)
# SW340 (Kazipara)
# SW341 (Chella Sonapur)
# SW342 (Nolsafa)
# SW344 (Ghog Bazar)
# SW346 (Pocharhat)
# SW40 (Ramu)
# SW53 (Bath Kuchi)
# SW57A (Rowshanpur)
# SW58A (Laksam)
# SW61 (Boragari)
# SW61.5 (Barati)
# SW63 (Chak-Rahimpur)
# SW67 (Kamaljani)
# SW68 (Tilli)
# SW68A (Elashin)
# SW75 (Patgram)
# SW78 (Kantanagar)
# SW8 (Basuri)
# SW84 (Ramgarh)
# SW96 (Islampur)
# SW96A (Jafarganj Road Crossing)

# %%
import mikeio
import pandas as pd
import os
import glob
from mikeio.eum import EUMType, EUMUnit, ItemInfo

# Output folder path (Just the folder path)
output_folder_path = r'G:\MJI\Non Tidal (172 nos.)\Output\Problem (Solved)\Fortnightly_Avg'


for file in glob.glob(r'G:\MJI\Non Tidal (172 nos.)\Output\Problem (Solved)\Fortnightly_Avg\*.xlsx'):

    # Splitting the path by seperator
    path_list = file.split(os.sep)  

    # File absolute path with file name and extension as xlsx
    df = pd.read_excel(file)
    df['Date/Time'] = pd.to_datetime(df['Date/Time'], format = "%Y/%m/%d")

    # Setting 'Date' column as dataframe index
    df.set_index(df['Date/Time'], inplace=True)
    v_df = df['Modified']

    # Output file path and name with extension
    file_path = os.path.join(output_folder_path, '{}.dfs0'.format(path_list[-1][:-5]))

    # Defining dfs0 item with item type
    item = [ItemInfo('Modified', EUMType.Water_Level, EUMUnit.meter)]

    # Saving the dfs0 file
    v_df.to_dfs0(file_path,items=item,title='{}'.format(path_list[-1][:-21]))
    
    print(path_list[-1][:-21])
# Out:
# SW101 (Kamarkhali Transit)
# SW109 (Bibir Bazar)
# SW11.5 (Nalkasengati)
# SW110 (Cumilla)
# SW113 (Kangsanagar)
# SW114 (Jibanpur_Gumti)
# SW117 (Narayanhat)
# SW119.1 (Panchpukuria)
# SW124 (Thandachari)
# SW131.5 (Laurergarh Saktiarkhola)
# SW138 (Sofiabad)
# SW139 (Bardeswari)
# SW140 (Panchgarh)
# SW141 (Debiganj)
# SW142 (Khansama)
# SW144 (Chak Hariharpur)
# SW145 (Mohadebpur)
# SW149.1 (Gumani Rly. Bridge)
# SW150 (Dohakolaanga)
# SW156A (Kundal)
# SW157 (Ballah)
# SW158 (Chunarghat)
# SW158.1 (Shaistaganj)
# SW159 (Habiganj)
# SW161 (Tahirpur)
# SW205A (Insafnagar)
# SW212 (Parshuram)
# SW225 (Jamalpur)
# SW227 (Offtake of Suti)
# SW228.5 (Mymensingh)
# SW233A (Jaflong_Spill)
# SW235A (Prannagar)
# SW262 (Bijoypur)
# SW263 (Durgapur)
# SW282 (Bhitagarh)
# SW285 (Thakurgaon)
# SW287 (Kodalkatigaon)
# SW293 (Kaliganj)
# SW305.5 (Ghoramaraghat)
# SW314 (Ghosegaon)
# SW333 (Muslimpur)
# SW334 (Mirar Bazar)
# SW336 (Bujruk)
# SW338 (Cansart)
# SW338.5 (Ramkrishnapur)
# SW34 (Nakuagaon)
# SW340 (Kazipara)
# SW341 (Chella Sonapur)
# SW342 (Nolsafa)
# SW344 (Ghog Bazar)
# SW346 (Pocharhat)
# SW40 (Ramu)
# SW53 (Bath Kuchi)
# SW57A (Rowshanpur)
# SW58A (Laksam)
# SW61 (Boragari)
# SW61.5 (Barati)
# SW63 (Chak-Rahimpur)
# SW67 (Kamaljani)
# SW68 (Tilli)
# SW68A (Elashin)
# SW75 (Patgram)
# SW78 (Kantanagar)
# SW8 (Basuri)
# SW84 (Ramgarh)
# SW96 (Islampur)
# SW96A (Jafarganj Road Crossing)

# %%
import mikeio
import pandas as pd
import os
import glob
from mikeio.eum import EUMType, EUMUnit, ItemInfo

# Output folder path (Just the folder path)
output_folder_path = r'G:\MJI\Non Tidal (172 nos.)\Output\Problem (Solved)\Fortnightly_Median_Day_Avg'


for file in glob.glob(r'G:\MJI\Non Tidal (172 nos.)\Output\Problem (Solved)\Fortnightly_Median_Day_Avg\*.xlsx'):

    # Splitting the path by seperator
    path_list = file.split(os.sep)  

    # File absolute path with file name and extension as xlsx
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Date'], format = "%Y/%m/%d")

    # Setting 'Date' column as dataframe index
    df.set_index(df['Date'], inplace=True)
    v_df = df['Modified']

    # Output file path and name with extension
    file_path = os.path.join(output_folder_path, '{}.dfs0'.format(path_list[-1][:-5]))

    # Defining dfs0 item with item type
    item = [ItemInfo('Modified', EUMType.Water_Level, EUMUnit.meter)]

    # Saving the dfs0 file
    v_df.to_dfs0(file_path,items=item,title='{}'.format(path_list[-1][:-32]))
    
    print(path_list[-1][:-32])
# Out:
# SW101 (Kamarkhali Transit)
# SW109 (Bibir Bazar)
# SW11.5 (Nalkasengati)
# SW110 (Cumilla)
# SW113 (Kangsanagar)
# SW114 (Jibanpur_Gumti)
# SW117 (Narayanhat)
# SW119.1 (Panchpukuria)
# SW124 (Thandachari)
# SW131.5 (Laurergarh Saktiarkhola)
# SW138 (Sofiabad)
# SW139 (Bardeswari)
# SW140 (Panchgarh)
# SW141 (Debiganj)
# SW142 (Khansama)
# SW144 (Chak Hariharpur)
# SW145 (Mohadebpur)
# SW149.1 (Gumani Rly. Bridge)
# SW150 (Dohakolaanga)
# SW156A (Kundal)
# SW157 (Ballah)
# SW158 (Chunarghat)
# SW158.1 (Shaistaganj)
# SW159 (Habiganj)
# SW161 (Tahirpur)
# SW205A (Insafnagar)
# SW212 (Parshuram)
# SW225 (Jamalpur)
# SW227 (Offtake of Suti)
# SW228.5 (Mymensingh)
# SW233A (Jaflong_Spill)
# SW235A (Prannagar)
# SW262 (Bijoypur)
# SW263 (Durgapur)
# SW282 (Bhitagarh)
# SW285 (Thakurgaon)
# SW287 (Kodalkatigaon)
# SW293 (Kaliganj)
# SW305.5 (Ghoramaraghat)
# SW314 (Ghosegaon)
# SW333 (Muslimpur)
# SW334 (Mirar Bazar)
# SW336 (Bujruk)
# SW338 (Cansart)
# SW338.5 (Ramkrishnapur)
# SW34 (Nakuagaon)
# SW340 (Kazipara)
# SW341 (Chella Sonapur)
# SW342 (Nolsafa)
# SW344 (Ghog Bazar)
# SW346 (Pocharhat)
# SW40 (Ramu)
# SW53 (Bath Kuchi)
# SW57A (Rowshanpur)
# SW58A (Laksam)
# SW61 (Boragari)
# SW61.5 (Barati)
# SW63 (Chak-Rahimpur)
# SW67 (Kamaljani)
# SW68 (Tilli)
# SW68A (Elashin)
# SW75 (Patgram)
# SW78 (Kantanagar)
# SW8 (Basuri)
# SW84 (Ramgarh)
# SW96 (Islampur)
# SW96A (Jafarganj Road Crossing)
