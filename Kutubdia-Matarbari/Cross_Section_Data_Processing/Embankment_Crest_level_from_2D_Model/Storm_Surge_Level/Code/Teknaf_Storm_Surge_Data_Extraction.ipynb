# %%
import mikeio
import os
import glob
import pandas as pd
import numpy as np


file_list = []
time_step_list = []
df = pd.read_excel(r"G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Storm_Surge_Data_Extraction_Result_File_List.xlsx")

for name,time in zip(df['File_Name'],df['Time_Step']):
    file_name = '{}.dfsu'.format(name)
    file_list.append(file_name)
    time_step_list.append(time)
    
file_df = pd.DataFrame({'File_Name':file_list,'Time_Step':time_step_list})




pfs = mikeio.read_pfs(r"G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Teknaf_E_742922_N_296337.dxfm")


out_folder = r'G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output'

for file in glob.glob(r'\\10.0.0.33\New folder (D)\Long Term Strom Surge_2020\Strom Surge Model Setup_2021\Sim\**\Result\*.dfsu'):
    

    folder_path = file.split(os.sep)
    dfsu_file_name = folder_path[-1]
    name1 = folder_path[-1].split('.dfsu')
    name = name1[0]
    

    if dfsu_file_name in file_list:
        
        n_df = file_df[file_df['File_Name'] == dfsu_file_name]
        time = int(n_df['Time_Step'].values)
        
        input_folder = r'\\10.0.0.33\New folder (D)\Long Term Strom Surge_2020\Strom Surge Model Setup_2021\Sim\{}\Result\{}.dfsu'.format(folder_path[-3],name)


        output_all_key_dict = pfs.DataExtractionFM.OUTPUTS.keys()
        output_list = list(output_all_key_dict)[3:]

        for output_x in output_list:
            
            pfs.DataExtractionFM.OUTPUTS[output_x].last_time_step = time-1
            
            x = pfs.DataExtractionFM.OUTPUTS[output_x].file_name.split('_')[0]
            y = pfs.DataExtractionFM.OUTPUTS[output_x].file_name.split('_')[-1][-6:]

            r_output = '{}_{}_{}'.format(x,name,y)

            pfs.DataExtractionFM.OUTPUTS[output_x].file_name = r_output


        dxfm_file_input = '|{}|'.format(input_folder)

        pfs.DataExtractionFM.INPUT.file_name = dxfm_file_input

        dxfm_out_folder = os.path.join(out_folder,name)

        os.mkdir(dxfm_out_folder)

        dxfm_file_name = r'{}\{}.dxfm'.format(dxfm_out_folder, name)

        pfs.write(dxfm_file_name)

        print(name)

    else: 
        pass
# Out:
# 1960_Base_HT_New
# 1960_Base_LT_New
# 1960_Base_Org_New
# 1960_CC_HT_2050
# 1960_CC_LT_2050
# 1960_CC_Org_2050
# 1961_Base_HT_New
# 1961_Base_LT_New
# 1961_Base_Org_New
# 1961_CC_HT_2050
# 1961_CC_LT_2050
# 1961_CC_Org_2050
# 1963_Base_HT_New
# 1963_Base_LT_New
# 1963_Base_Org_New
# 1963_CC_HT_2050
# 1963_CC_LT_2050
# 1963_CC_Org_2050
# 1965_Dec_Base_LT_New
# 1965_Dec_Base_Org_New
# 1965_Dec_CC_LT_2050
# 1965_Dec_CC_Org_2050
# 1965_May_Base_HT_New
# 1965_May_Base_LT_New
# 1965_May_Base_Org_New
# 1965_May_CC_HT_2050
# 1965_May_CC_LT_2050
# 1965_May_CC_Org_2050
# 1966_Base_HT_New
# 1966_Base_LT_New
# 1966_Base_Org_New
# 1966_CC_HT_2050
# 1966_CC_LT_2050
# 1966_CC_Org_2050
# 1970_Base_HT_New
# 1970_Base_LT_New
# 1970_Base_Org_New
# 1970_CC_HT_2050
# 1970_CC_LT_2050
# 1970_CC_Org_2050
# 1974_Base_HT_New
# 1974_Base_LT_New
# 1974_Base_Org_New
# 1974_CC_HT_2050
# 1974_CC_LT_2050
# 1974_CC_Org_2050
# 1983_Base_HT_New
# 1983_Base_LT_New
# 1983_Base_Org_New
# 1983_CC_HT_2050
# 1983_CC_LT_2050
# 1983_CC_Org_2050
# 1985_Base_HT_New
# 1985_Base_LT_New
# 1985_Base_Org_New
# 1985_CC_HT_2050
# 1985_CC_LT_2050
# 1985_CC_Org_2050
# 1986_Base_HT_New
# 1986_Base_LT_New
# 1986_Base_Org_New
# 1986_CC_HT_2050
# 1986_CC_LT_2050
# 1986_CC_Org_2050_NEW
# 1988_Base_HT_New
# 1988_Base_LT_New
# 1988_Base_Org_New
# 1988_CC_HT_2050
# 1988_CC_LT_2050
# 1988_CC_Org_2050
# 1991_Base_HT_New
# 1991_Base_LT_New
# 1991_Base_Org_New
# 1991_CC_HT_2050
# 1991_CC_LT_2050
# 1991_CC_Org_2050
# 1995_Base_HT_New
# 1995_Base_LT_New
# 1995_Base_Org_New
# 1995_CC_HT_2050
# 1995_CC_LT_2050
# 1995_CC_Org_2050
# 1997_May_Base_LT_New
# 1997_May_Base_Org_New
# 1997_May_CC_LT_2050
# 1997_May_CC_Org_2050
# 1997_Sep_Base_HT_New
# 1997_Sep_Base_LT_New
# 1997_Sep_Base_Org_New
# 1997_Sep_CC_HT_2050
# 1997_Sep_CC_LT_2050
# 1997_Sep_CC_Org_2050
# 1998_Base_HT_New
# 1998_Base_Org_New
# 1998_CC_HT_2050
# 1998_CC_Org_2050
# 2007_CC_HT_2050
# 2007_CC_LT_2050
# 2007_CC_Org_2050
# Sidr_Base_2007_HT_New
# Sidr_Base_LT_New
# Sidr_Base_Org_New
# 2009_Base._LT_New
# 2009_Base_HT_New
# 2009_Base_Org_New
# 2009_CC_HT_2050
# 2009_CC_LT_2050
# 2009_CC_Org_2050

# %%
import glob
import os

txt = open(r"G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\Teknaf_storm_surge_batch.txt", 'w')

for file in glob.glob(r'G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\**\*.dxfm'):
    txt_format = 'start /w MzLaunch.exe "{}" -x\n'.format(file)
    txt.write(txt_format)
    print(txt_format)
    
txt.close()
# Out:
# start /w MzLaunch.exe "G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\1960_Base_HT_New\1960_Base_HT_New.dxfm" -x
#
# start /w MzLaunch.exe "G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\1960_Base_LT_New\1960_Base_LT_New.dxfm" -x
#
# start /w MzLaunch.exe "G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\1960_Base_Org_New\1960_Base_Org_New.dxfm" -x
#
# start /w MzLaunch.exe "G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\1960_CC_HT_2050\1960_CC_HT_2050.dxfm" -x
#
# start /w MzLaunch.exe "G:\MJI\SKZ\Script\Extracting Profile Series From DFSU File\Teknaf_Point\Output\