# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df = pd.read_csv(r"D:\Script\From_RAJ\Code\TmaxData.csv")

# %%
df
# Out:
#                date  ('88.625', '26.625')  ('88.625', '26.875')  \
# 0        1951-01-01                 17.35                 21.56
# 1        1951-01-02                 19.75                 24.30
# 2        1951-01-03                 19.40                 23.87
# 3        1951-01-04                 19.87                 24.34
# 4        1951-01-05                 19.00                 23.24
# ...             ...                   ...                   ...
# 1120221  2100-12-27                 26.81                 30.44
# 1120222  2100-12-28                 27.65                 31.38
# 1120223  2100-12-29                 28.20                 32.09
# 1120224  2100-12-30                 28.53                 32.12
# 1120225  2100-12-31                 28.65                 32.57
#
#          ('88.625', '27.125')  ('88.625', '27.375')  ('88.875', '26.125')  \
# 0                       20.99                 19.46                 18.92
# 1                       23.95                 22.66                 20.80
# 2                       23.44                 22.05                 20.52
# 3                       23.91                 22.53                 21.24
# 4                       22.60                 21.04                 20.79
# ...                       ...                   ...                   ...
# 1120221                 29.47                 27.65                 29.90
# 1120222                 30.47                 28.76                 30.16
# 1120223                 31.22                 29.51                 30.42
# 1120224                 30.95                 29.02                 30.74
# 1120225                 31.61                 29.83                 30.78
#
#          ('88.875', '26.375')  ('88.875', '26.625')  ('88.875', '26.875')  \
# 0                       18.14                 20.03                 22.84
# 1                       19.93                 22.33                 25.46
# 2                       19.67                 21.98                 25.02
# 3                       20.17                 22.42                 25.48
# 4                       19.55                 21.58                 24.40
# ...                       ...                   ...                   ...
# 1120221                 27.92                 29.30                 31.57
# 1120222                 28.40                 30.14                 32.50
# 1120223                 28.81                 30.71                 33.24
# 1120224                 29.22                 31.00                 33.25
# 1120225                 29.26                 31.16                 33.73
#
#          ('88.875', '27.125')  ...  ('89.375', '25.875')  \
# 0                        9.05  ...                 19.32
# 1                       11.55  ...                 20.04
# 2                       11.11  ...                 19.65
# 3                       11.50  ...                 20.82
# 4                       10.41  ...                 20.58
# ...                       ...  ...                   ...
# 1120221                 18.20  ...                 29.99
# 1120222                 19.33  ...                 30.11
# 1120223                 20.23  ...                 30.32
# 1120224                 19.88  ...                 30.66
# 1120225                 20.76  ...                 30.73
#
#          ('89.375', '26.125')  ('89.375', '26.375')  ('89.375', '26.625')  \
# 0                       18.97                 18.14                 18.43
# 1                       20.61                 19.77                 20.48
# 2                       20.36                 19.50                 20.14
# 3                       21.12                 19.95                 20.52
# 4                       20.63                 19.37                 19.76
# ...                       ...                   ...                   ...
# 1120221                 29.82                 27.44                 27.33
# 1120222                 30.08                 27.93                 28.08
# 1120223                 30.40                 28.39                 28.73
# 1120224                 30.70                 28.78                 29.00
# 1120225                 30.76                 28.85                 29.19
#
#          ('89.375', '26.875')  ('89.625', '25.875')  ('89.625', '26.125')  \
# 0                       15.82                 19.02                 18.85
# 1                       18.32                 19.93                 20.45
# 2                       17.88                 19.58                 20.17
# 3                       18.30                 20.64                 20.94
# 4                       17.29                 20.43                 20.47
# ...                       ...                   ...                   ...
# 1120221                 25.39                 29.72                 29.64
# 1120222                 26.31                 29.84                 29.89
# 1120223                 27.18                 30.08                 30.24
# 1120224                 27.16                 30.41                 30.55
# 1120225                 27.68                 30.48                 30.61
#
#          ('89.875', '25.875')       model  projection
# 0                       18.58  ACCESS-CM2  historical
# 1                       19.84  ACCESS-CM2  historical
# 2                       19.43  ACCESS-CM2  historical
# 3                       20.49  ACCESS-CM2  historical
# 4                       20.35  ACCESS-CM2  historical
# ...                       ...         ...         ...
# 1120221                 29.52  NorESM2-MM      ssp585
# 1120222                 29.63  NorESM2-MM      ssp585
# 1120223                 29.90  NorESM2-MM      ssp585
# 1120224                 30.26  NorESM2-MM      ssp585
# 1120225                 30.32  NorESM2-MM      ssp585
#
# [1120226 rows x 28 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Year'] = df['date'].dt.year
df['Month'] = df['date'].dt.month
df['Day'] = df['date'].dt.day
df
# Out:
#               date  ('88.625', '26.625')  ('88.625', '26.875')  \
# 0       1951-01-01                 17.35                 21.56
# 1       1951-01-02                 19.75                 24.30
# 2       1951-01-03                 19.40                 23.87
# 3       1951-01-04                 19.87                 24.34
# 4       1951-01-05                 19.00                 23.24
# ...            ...                   ...                   ...
# 1120221 2100-12-27                 26.81                 30.44
# 1120222 2100-12-28                 27.65                 31.38
# 1120223 2100-12-29                 28.20                 32.09
# 1120224 2100-12-30                 28.53                 32.12
# 1120225 2100-12-31                 28.65                 32.57
#
#          ('88.625', '27.125')  ('88.625', '27.375')  ('88.875', '26.125')  \
# 0                       20.99                 19.46                 18.92
# 1                       23.95                 22.66                 20.80
# 2                       23.44                 22.05                 20.52
# 3                       23.91                 22.53                 21.24
# 4                       22.60                 21.04                 20.79
# ...                       ...                   ...                   ...
# 1120221                 29.47                 27.65                 29.90
# 1120222                 30.47                 28.76                 30.16
# 1120223                 31.22                 29.51                 30.42
# 1120224                 30.95                 29.02                 30.74
# 1120225                 31.61                 29.83                 30.78
#
#          ('88.875', '26.375')  ('88.875', '26.625')  ('88.875', '26.875')  \
# 0                       18.14                 20.03                 22.84
# 1                       19.93                 22.33                 25.46
# 2                       19.67                 21.98                 25.02
# 3                       20.17                 22.42                 25.48
# 4                       19.55                 21.58                 24.40
# ...                       ...                   ...                   ...
# 1120221                 27.92                 29.30                 31.57
# 1120222                 28.40                 30.14                 32.50
# 1120223                 28.81                 30.71                 33.24
# 1120224                 29.22                 31.00                 33.25
# 1120225                 29.26                 31.16                 33.73
#
#          ('88.875', '27.125')  ...  ('89.375', '26.625')  \
# 0                        9.05  ...                 18.43
# 1                       11.55  ...                 20.48
# 2                       11.11  ...                 20.14
# 3                       11.50  ...                 20.52
# 4                       10.41  ...                 19.76
# ...                       ...  ...                   ...
# 1120221                 18.20  ...                 27.33
# 1120222                 19.33  ...                 28.08
# 1120223                 20.23  ...                 28.73
# 1120224                 19.88  ...                 29.00
# 1120225                 20.76  ...                 29.19
#
#          ('89.375', '26.875')  ('89.625', '25.875')  ('89.625', '26.125')  \
# 0                       15.82                 19.02                 18.85
# 1                       18.32                 19.93                 20.45
# 2                       17.88                 19.58                 20.17
# 3                       18.30                 20.64                 20.94
# 4                       17.29                 20.43                 20.47
# ...                       ...                   ...                   ...
# 1120221                 25.39                 29.72                 29.64
# 1120222                 26.31                 29.84                 29.89
# 1120223                 27.18                 30.08                 30.24
# 1120224                 27.16                 30.41                 30.55
# 1120225                 27.68                 30.48                 30.61
#
#          ('89.875', '25.875')       model  projection  Year  Month  Day
# 0                       18.58  ACCESS-CM2  historical  1951      1    1
# 1                       19.84  ACCESS-CM2  historical  1951      1    2
# 2                       19.43  ACCESS-CM2  historical  1951      1    3
# 3                       20.49  ACCESS-CM2  historical  1951      1    4
# 4                       20.35  ACCESS-CM2  historical  1951      1    5
# ...                       ...         ...         ...   ...    ...  ...
# 1120221                 29.52  NorESM2-MM      ssp585  2100     12   27
# 1120222                 29.63  NorESM2-MM      ssp585  2100     12   28
# 1120223                 29.90  NorESM2-MM      ssp585  2100     12   29
# 1120224                 30.26  NorESM2-MM      ssp585  2100     12   30
# 1120225                 30.32  NorESM2-MM      ssp585  2100     12   31
#
# [1120226 rows x 31 columns]

# %%
df['Spatial_Mean']= df[df.columns[1:-8]].mean(axis=1)
spatial_mean_df = df[['model', 'projection', 'Year', 'Month', 'Day', 'date', 'Spatial_Mean']]
spatial_mean_df
# Out:
#               model  projection  Year  Month  Day       date  Spatial_Mean
# 0        ACCESS-CM2  historical  1951      1    1 1951-01-01     16.160455
# 1        ACCESS-CM2  historical  1951      1    2 1951-01-02     18.362727
# 2        ACCESS-CM2  historical  1951      1    3 1951-01-03     17.954545
# 3        ACCESS-CM2  historical  1951      1    4 1951-01-04     18.516818
# 4        ACCESS-CM2  historical  1951      1    5 1951-01-05     17.657727
# ...             ...         ...   ...    ...  ...        ...           ...
# 1120221  NorESM2-MM      ssp585  2100     12   27 2100-12-27     25.687727
# 1120222  NorESM2-MM      ssp585  2100     12   28 2100-12-28     26.434091
# 1120223  NorESM2-MM      ssp585  2100     12   29 2100-12-29     27.050000
# 1120224  NorESM2-MM      ssp585  2100     12   30 2100-12-30     27.100455
# 1120225  NorESM2-MM      ssp585  2100     12   31 2100-12-31     27.497727
#
# [1120226 rows x 7 columns]

# %%
annual_mean_df = spatial_mean_df.groupby(['model', 'projection', 'Year'])['Spatial_Mean'].mean().reset_index()
annual_mean_df
# Out:
#            model  projection  Year  Spatial_Mean
# 0     ACCESS-CM2  historical  1951     26.857844
# 1     ACCESS-CM2  historical  1952     26.627945
# 2     ACCESS-CM2  historical  1953     26.273056
# 3     ACCESS-CM2  historical  1954     26.705351
# 4     ACCESS-CM2  historical  1955     26.114785
# ...          ...         ...   ...           ...
# 3063  NorESM2-MM      ssp585  2096     29.774928
# 3064  NorESM2-MM      ssp585  2097     30.243340
# 3065  NorESM2-MM      ssp585  2098     30.666308
# 3066  NorESM2-MM      ssp585  2099     29.698649
# 3067  NorESM2-MM      ssp585  2100     30.804177
#
# [3068 rows x 4 columns]

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
font = {'family' : 'Times New Roman',              
        'weight' : 'normal',  
        'size'   : 10}

plt.rc('font',**font)
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=10)

custom_palette = ["black", "purple", "red"]

sns.lineplot(data=annual_mean_df, x='Year', y='Spatial_Mean', hue='projection', 
             errorbar=('ci', 95), palette = custom_palette, ax = ax)

# Customize plot
ax.set_xlim(1960, 2100)
ax.set_ylim(24, 32)
ax.set_title('CMIP6 Historical and Projected Maximum Temperature', fontsize=12, fontweight='bold')
ax.set_xlabel('Year', fontsize=12, fontweight='bold')
ax.set_ylabel('Average Annual Maximum Temperature (°C)',  fontsize=12, fontweight='bold')

ax.axvline(2026, color='black', linewidth=1, linestyle='--', c='dimgrey')
ax.axvline(2050, color='black', linewidth=1, linestyle='--', c='dimgrey')
ax.axvline(2075, color='black', linewidth=1, linestyle='--', c='dimgrey')

# Shade regions between vertical lines
# ax.axvspan(2025, 2050, color='grey', alpha=0.05, label='Near-term')
# ax.axvspan(2050, 2075, color='grey', alpha=0.10, label='Mid-term')
# ax.axvspan(2075, 2100, color='grey', alpha=0.15, label='long-term')

ax.text(2038, 0.92, 'Near \n (2026-2050)', ha='center', va='center', transform=ax.get_xaxis_transform(), 
        fontweight='bold', fontstyle='italic', fontsize=12)
ax.text(2062.5, 0.92, 'Mid \n (2051-2075)', ha='center', va='center', transform=ax.get_xaxis_transform(), 
        fontweight='bold', fontstyle='italic', fontsize=12)
ax.text(2087.5, 0.92, 'Long \n (2076-2100)', ha='center', va='center', transform=ax.get_xaxis_transform(), 
        fontweight='bold', fontstyle='italic', fontsize=12)

handles, labels = ax.get_legend_handles_labels()
legend = ax.legend(handles, ['Historical', 'SSP245', 'SSP585'],
                   title='Projection', loc='upper left', bbox_to_anchor=(0, 1))
# legend.get_title().set_fontsize(10)
legend.get_title().set_fontweight('bold')
legend.get_title().set_horizontalalignment('left')
# plt.savefig(r'D:\Script\From_RAJ\Output\Maximum_Temperature_Trend_Analysis.jpg', 
#             dpi=600, bbox_inches = 'tight')
plt.show()

# %%
historical_df = annual_mean_df[annual_mean_df['projection'] == 'historical']
historical_df_mean = historical_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print(historical_df_mean['Spatial_Mean'].min())
print(historical_df_mean['Spatial_Mean'].max())
# Out:
# 25.998852861301433
# 26.946246575342464

# %%
ssp245_df = annual_mean_df[annual_mean_df['projection'] == 'ssp245']
near_ssp245_df = ssp245_df[(ssp245_df['Year']>=2026) & (ssp245_df['Year']<=2050)]
near_ssp245_df_mean = near_ssp245_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print('Near-term (SSP245) Minimum: ', near_ssp245_df_mean['Spatial_Mean'].min())
print('Near-term (SSP245) Maximum: ', near_ssp245_df_mean['Spatial_Mean'].max())
# Out:
# Near-term (SSP245) Minimum:  26.80485353003161
# Near-term (SSP245) Maximum:  27.523704377813967

# %%
ssp585_df = annual_mean_df[annual_mean_df['projection'] == 'ssp585']
near_ssp585_df = ssp585_df[(ssp585_df['Year']>=2026) & (ssp585_df['Year']<=2050)]
near_ssp585_df_mean = near_ssp585_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print('Near-term (SSP585) Minimum: ', near_ssp585_df_mean['Spatial_Mean'].min())
print('Near-term (SSP585) Maximum: ', near_ssp585_df_mean['Spatial_Mean'].max())
# Out:
# Near-term (SSP585) Minimum:  26.852124054028163
# Near-term (SSP585) Maximum:  28.064300986684547

# %%
ssp245_df = annual_mean_df[annual_mean_df['projection'] == 'ssp245']
mid_ssp245_df = ssp245_df[(ssp245_df['Year']>=2051) & (ssp245_df['Year']<=2075)]
mid_ssp245_df_mean = mid_ssp245_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print('Mid-term (SSP245) Minimum: ', mid_ssp245_df_mean['Spatial_Mean'].min())
print('Mid-term (SSP245) Maximum: ', mid_ssp245_df_mean['Spatial_Mean'].max())
# Out:
# Mid-term (SSP245) Minimum:  27.607123575055084
# Mid-term (SSP245) Maximum:  28.25152486184375

# %%
ssp585_df = annual_mean_df[annual_mean_df['projection'] == 'ssp585']
mid_ssp585_df = ssp585_df[(ssp585_df['Year']>=2051) & (ssp585_df['Year']<=2075)]
mid_ssp585_df_mean = mid_ssp585_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print('Mid-term (SSP585) Minimum: ', mid_ssp585_df_mean['Spatial_Mean'].min())
print('Mid-term (SSP585) Maximum: ', mid_ssp585_df_mean['Spatial_Mean'].max())
# Out:
# Mid-term (SSP585) Minimum:  27.901497844621133
# Mid-term (SSP585) Maximum:  28.995762525146088

# %%
ssp245_df = annual_mean_df[annual_mean_df['projection'] == 'ssp245']
long_ssp245_df = ssp245_df[(ssp245_df['Year']>=2076) & (ssp245_df['Year']<=2100)]
long_ssp245_df_mean = long_ssp245_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print('Long-term (SSP245) Minimum: ', long_ssp245_df_mean['Spatial_Mean'].min())
print('Long-term (SSP245) Maximum: ', long_ssp245_df_mean['Spatial_Mean'].max())
# Out:
# Long-term (SSP245) Minimum:  27.95218076444104
# Long-term (SSP245) Maximum:  28.466795670083343

# %%
ssp585_df = annual_mean_df[annual_mean_df['projection'] == 'ssp585']
long_ssp585_df = ssp585_df[(ssp585_df['Year']>=2076) & (ssp585_df['Year']<=2100)]
long_ssp585_df_mean = long_ssp585_df.groupby(['projection','Year'])['Spatial_Mean'].mean().reset_index()
print('Long-term (SSP585) Minimum: ', long_ssp585_df_mean['Spatial_Mean'].min())
print('Long-term (SSP585) Maximum: ', long_ssp585_df_mean['Spatial_Mean'].max())
# Out:
# Long-term (SSP585) Minimum:  29.10256437110311
# Long-term (SSP585) Maximum:  30.281080563272344
