# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns
import datetime
import calendar

# %%
df = pd.read_csv(r"D:\Script\From_RAJ\Code\TminData.csv")

# %%
df
# Out:
#                date  ('88.625', '26.625')  ('88.625', '26.875')  \
# 0        1951-01-01                  6.75                 10.45
# 1        1951-01-02                  6.35                 10.22
# 2        1951-01-03                  6.99                 11.12
# 3        1951-01-04                  7.32                 11.64
# 4        1951-01-05                  8.48                 12.77
# ...             ...                   ...                   ...
# 1120221  2100-12-27                 14.41                 18.61
# 1120222  2100-12-28                 14.45                 18.77
# 1120223  2100-12-29                 15.73                 20.16
# 1120224  2100-12-30                 16.09                 20.12
# 1120225  2100-12-31                 16.05                 20.08
#
#          ('88.625', '27.125')  ('88.625', '27.375')  ('88.875', '26.125')  \
# 0                        9.36                  7.44                  9.22
# 1                        9.27                  7.45                  7.70
# 2                       10.35                  8.65                  8.73
# 3                       11.03                  9.44                  7.68
# 4                       12.12                 10.47                  8.85
# ...                       ...                   ...                   ...
# 1120221                 17.84                 16.08                 17.36
# 1120222                 18.13                 16.57                 17.20
# 1120223                 19.68                 18.25                 17.90
# 1120224                 19.22                 17.21                 18.46
# 1120225                 19.17                 17.14                 18.37
#
#          ('88.875', '26.375')  ('88.875', '26.625')  ('88.875', '26.875')  \
# 0                        8.10                  9.51                 11.70
# 1                        7.57                  9.12                 11.46
# 2                        7.98                  9.70                 12.38
# 3                        7.89                  9.96                 12.84
# 4                        8.95                 11.18                 14.03
# ...                       ...                   ...                   ...
# 1120221                 15.23                 17.05                 19.71
# 1120222                 15.15                 17.09                 19.91
# 1120223                 16.20                 18.31                 21.29
# 1120224                 16.75                 18.68                 21.26
# 1120225                 16.69                 18.65                 21.26
#
#          ('88.875', '27.125')  ...  ('89.375', '25.875')  \
# 0                       -5.38  ...                 11.12
# 1                       -5.56  ...                  9.02
# 2                       -3.34  ...                  9.99
# 3                       -1.90  ...                  8.51
# 4                        0.39  ...                  8.90
# ...                       ...  ...                   ...
# 1120221                  7.33  ...                 18.02
# 1120222                  7.62  ...                 17.74
# 1120223                  8.88  ...                 18.23
# 1120224                  8.50  ...                 18.78
# 1120225                  8.51  ...                 18.71
#
#          ('89.375', '26.125')  ('89.375', '26.375')  ('89.375', '26.625')  \
# 0                        9.98                  8.34                  7.97
# 1                        8.42                  7.74                  7.56
# 2                        9.13                  8.03                  8.09
# 3                        8.33                  7.91                  8.22
# 4                        9.60                  9.11                  9.57
# ...                       ...                   ...                   ...
# 1120221                 17.89                 15.26                 15.34
# 1120222                 17.72                 15.16                 15.39
# 1120223                 18.38                 16.08                 16.51
# 1120224                 18.91                 16.64                 16.87
# 1120225                 18.86                 16.60                 16.88
#
#          ('89.375', '26.875')  ('89.625', '25.875')  ('89.625', '26.125')  \
# 0                        2.05                 11.60                 10.56
# 1                        1.54                  9.41                  8.82
# 2                        3.60                 10.10                  9.39
# 3                        4.49                  8.77                  8.59
# 4                        7.06                  9.20                  9.89
# ...                       ...                   ...                   ...
# 1120221                 13.76                 18.24                 18.11
# 1120222                 13.98                 17.98                 17.94
# 1120223                 15.07                 18.43                 18.57
# 1120224                 15.06                 18.98                 19.07
# 1120225                 15.14                 18.93                 19.04
#
#          ('89.875', '25.875')       model  projection
# 0                       12.13  ACCESS-CM2  historical
# 1                        9.84  ACCESS-CM2  historical
# 2                       10.14  ACCESS-CM2  historical
# 3                        8.92  ACCESS-CM2  historical
# 4                        9.32  ACCESS-CM2  historical
# ...                       ...         ...         ...
# 1120221                 18.37  NorESM2-MM      ssp585
# 1120222                 18.12  NorESM2-MM      ssp585
# 1120223                 18.54  NorESM2-MM      ssp585
# 1120224                 19.06  NorESM2-MM      ssp585
# 1120225                 19.04  NorESM2-MM      ssp585
#
# [1120226 rows x 28 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#               date  ('88.625', '26.625')  ('88.625', '26.875')  \
# 0       1951-01-01                  6.75                 10.45
# 1       1951-01-02                  6.35                 10.22
# 2       1951-01-03                  6.99                 11.12
# 3       1951-01-04                  7.32                 11.64
# 4       1951-01-05                  8.48                 12.77
# ...            ...                   ...                   ...
# 1120221 2100-12-27                 14.41                 18.61
# 1120222 2100-12-28                 14.45                 18.77
# 1120223 2100-12-29                 15.73                 20.16
# 1120224 2100-12-30                 16.09                 20.12
# 1120225 2100-12-31                 16.05                 20.08
#
#          ('88.625', '27.125')  ('88.625', '27.375')  ('88.875', '26.125')  \
# 0                        9.36                  7.44                  9.22
# 1                        9.27                  7.45                  7.70
# 2                       10.35                  8.65                  8.73
# 3                       11.03                  9.44                  7.68
# 4                       12.12                 10.47                  8.85
# ...                       ...                   ...                   ...
# 1120221                 17.84                 16.08                 17.36
# 1120222                 18.13                 16.57                 17.20
# 1120223                 19.68                 18.25                 17.90
# 1120224                 19.22                 17.21                 18.46
# 1120225                 19.17                 17.14                 18.37
#
#          ('88.875', '26.375')  ('88.875', '26.625')  ('88.875', '26.875')  \
# 0                        8.10                  9.51                 11.70
# 1                        7.57                  9.12                 11.46
# 2                        7.98                  9.70                 12.38
# 3                        7.89                  9.96                 12.84
# 4                        8.95                 11.18                 14.03
# ...                       ...                   ...                   ...
# 1120221                 15.23                 17.05                 19.71
# 1120222                 15.15                 17.09                 19.91
# 1120223                 16.20                 18.31                 21.29
# 1120224                 16.75                 18.68                 21.26
# 1120225                 16.69                 18.65                 21.26
#
#          ('88.875', '27.125')  ...  ('89.375', '25.875')  \
# 0                       -5.38  ...                 11.12
# 1                       -5.56  ...                  9.02
# 2                       -3.34  ...                  9.99
# 3                       -1.90  ...                  8.51
# 4                        0.39  ...                  8.90
# ...                       ...  ...                   ...
# 1120221                  7.33  ...                 18.02
# 1120222                  7.62  ...                 17.74
# 1120223                  8.88  ...                 18.23
# 1120224                  8.50  ...                 18.78
# 1120225                  8.51  ...                 18.71
#
#          ('89.375', '26.125')  ('89.375', '26.375')  ('89.375', '26.625')  \
# 0                        9.98                  8.34                  7.97
# 1                        8.42                  7.74                  7.56
# 2                        9.13                  8.03                  8.09
# 3                        8.33                  7.91                  8.22
# 4                        9.60                  9.11                  9.57
# ...                       ...                   ...                   ...
# 1120221                 17.89                 15.26                 15.34
# 1120222                 17.72                 15.16                 15.39
# 1120223                 18.38                 16.08                 16.51
# 1120224                 18.91                 16.64                 16.87
# 1120225                 18.86                 16.60                 16.88
#
#          ('89.375', '26.875')  ('89.625', '25.875')  ('89.625', '26.125')  \
# 0                        2.05                 11.60                 10.56
# 1                        1.54                  9.41                  8.82
# 2                        3.60                 10.10                  9.39
# 3                        4.49                  8.77                  8.59
# 4                        7.06                  9.20                  9.89
# ...                       ...                   ...                   ...
# 1120221                 13.76                 18.24                 18.11
# 1120222                 13.98                 17.98                 17.94
# 1120223                 15.07                 18.43                 18.57
# 1120224                 15.06                 18.98                 19.07
# 1120225                 15.14                 18.93                 19.04
#
#          ('89.875', '25.875')       model  projection
# 0                       12.13  ACCESS-CM2  historical
# 1                        9.84  ACCESS-CM2  historical
# 2                       10.14  ACCESS-CM2  historical
# 3                        8.92  ACCESS-CM2  historical
# 4                        9.32  ACCESS-CM2  historical
# ...                       ...         ...         ...
# 1120221                 18.37  NorESM2-MM      ssp585
# 1120222                 18.12  NorESM2-MM      ssp585
# 1120223                 18.54  NorESM2-MM      ssp585
# 1120224                 19.06  NorESM2-MM      ssp585
# 1120225                 19.04  NorESM2-MM      ssp585
#
# [1120226 rows x 28 columns]

# %%
df['date'].dt.year
# Out:
# 0          1951
# 1          1951
# 2          1951
# 3          1951
# 4          1951
#            ...
# 1120221    2100
# 1120222    2100
# 1120223    2100
# 1120224    2100
# 1120225    2100
# Name: date, Length: 1120226, dtype: int32

# %%
df['Year'] = df['date'].dt.year
df['Month'] = df['date'].dt.month
df['Day'] = df['date'].dt.day
df
# Out:
#               date  ('88.625', '26.625')  ('88.625', '26.875')  \
# 0       1951-01-01                  6.75                 10.45
# 1       1951-01-02                  6.35                 10.22
# 2       1951-01-03                  6.99                 11.12
# 3       1951-01-04                  7.32                 11.64
# 4       1951-01-05                  8.48                 12.77
# ...            ...                   ...                   ...
# 1120221 2100-12-27                 14.41                 18.61
# 1120222 2100-12-28                 14.45                 18.77
# 1120223 2100-12-29                 15.73                 20.16
# 1120224 2100-12-30                 16.09                 20.12
# 1120225 2100-12-31                 16.05                 20.08
#
#          ('88.625', '27.125')  ('88.625', '27.375')  ('88.875', '26.125')  \
# 0                        9.36                  7.44                  9.22
# 1                        9.27                  7.45                  7.70
# 2                       10.35                  8.65                  8.73
# 3                       11.03                  9.44                  7.68
# 4                       12.12                 10.47                  8.85
# ...                       ...                   ...                   ...
# 1120221                 17.84                 16.08                 17.36
# 1120222                 18.13                 16.57                 17.20
# 1120223                 19.68                 18.25                 17.90
# 1120224                 19.22                 17.21                 18.46
# 1120225                 19.17                 17.14                 18.37
#
#          ('88.875', '26.375')  ('88.875', '26.625')  ('88.875', '26.875')  \
# 0                        8.10                  9.51                 11.70
# 1                        7.57                  9.12                 11.46
# 2                        7.98                  9.70                 12.38
# 3                        7.89                  9.96                 12.84
# 4                        8.95                 11.18                 14.03
# ...                       ...                   ...                   ...
# 1120221                 15.23                 17.05                 19.71
# 1120222                 15.15                 17.09                 19.91
# 1120223                 16.20                 18.31                 21.29
# 1120224                 16.75                 18.68                 21.26
# 1120225                 16.69                 18.65                 21.26
#
#          ('88.875', '27.125')  ...  ('89.375', '26.625')  \
# 0                       -5.38  ...                  7.97
# 1                       -5.56  ...                  7.56
# 2                       -3.34  ...                  8.09
# 3                       -1.90  ...                  8.22
# 4                        0.39  ...                  9.57
# ...                       ...  ...                   ...
# 1120221                  7.33  ...                 15.34
# 1120222                  7.62  ...                 15.39
# 1120223                  8.88  ...                 16.51
# 1120224                  8.50  ...                 16.87
# 1120225                  8.51  ...                 16.88
#
#          ('89.375', '26.875')  ('89.625', '25.875')  ('89.625', '26.125')  \
# 0                        2.05                 11.60                 10.56
# 1                        1.54                  9.41                  8.82
# 2                        3.60                 10.10                  9.39
# 3                        4.49                  8.77                  8.59
# 4                        7.06                  9.20                  9.89
# ...                       ...                   ...                   ...
# 1120221                 13.76                 18.24                 18.11
# 1120222                 13.98                 17.98                 17.94
# 1120223                 15.07                 18.43                 18.57
# 1120224                 15.06                 18.98                 19.07
# 1120225                 15.14                 18.93                 19.04
#
#          ('89.875', '25.875')       model  projection  Year  Month  Day
# 0                       12.13  ACCESS-CM2  historical  1951      1    1
# 1                        9.84  ACCESS-CM2  historical  1951      1    2
# 2                       10.14  ACCESS-CM2  historical  1951      1    3
# 3                        8.92  ACCESS-CM2  historical  1951      1    4
# 4                        9.32  ACCESS-CM2  historical  1951      1    5
# ...                       ...         ...         ...   ...    ...  ...
# 1120221                 18.37  NorESM2-MM      ssp585  2100     12   27
# 1120222                 18.12  NorESM2-MM      ssp585  2100     12   28
# 1120223                 18.54  NorESM2-MM      ssp585  2100     12   29
# 1120224                 19.06  NorESM2-MM      ssp585  2100     12   30
# 1120225                 19.04  NorESM2-MM      ssp585  2100     12   31
#
# [1120226 rows x 31 columns]

# %%
timespan_dict = {'Base': [1990, 2014],
                 'Short': [2026, 2050],
                 'Mid': [2051, 2075],
                 'Long': [2076, 2100]}

ts_conditions = [
                (df['date'].dt.year >= timespan_dict['Base'][0]) & (df['date'].dt.year <= timespan_dict['Base'][1]),
                (df['date'].dt.year >= timespan_dict['Short'][0]) & (df['date'].dt.year <= timespan_dict['Short'][1]),
                (df['date'].dt.year >= timespan_dict['Mid'][0]) & (df['date'].dt.year <= timespan_dict['Mid'][1]),
                (df['date'].dt.year >= timespan_dict['Long'][0]) & (df['date'].dt.year <= timespan_dict['Long'][1])
                ]

ts_choices = list(timespan_dict.keys())

df['time_span'] = np.select(ts_conditions, ts_choices, default='Historical')
df['Spatial_Mean']= df[df.columns[1:-8]].mean(axis=1)
spatial_mean_df = df[['time_span', 'model', 'projection', 'Year', 'Month', 'Day', 'date', 'Spatial_Mean']]
spatial_mean_df
# Out:
#           time_span       model  projection  Year  Month  Day       date  \
# 0        Historical  ACCESS-CM2  historical  1951      1    1 1951-01-01
# 1        Historical  ACCESS-CM2  historical  1951      1    2 1951-01-02
# 2        Historical  ACCESS-CM2  historical  1951      1    3 1951-01-03
# 3        Historical  ACCESS-CM2  historical  1951      1    4 1951-01-04
# 4        Historical  ACCESS-CM2  historical  1951      1    5 1951-01-05
# ...             ...         ...         ...   ...    ...  ...        ...
# 1120221        Long  NorESM2-MM      ssp585  2100     12   27 2100-12-27
# 1120222        Long  NorESM2-MM      ssp585  2100     12   28 2100-12-28
# 1120223        Long  NorESM2-MM      ssp585  2100     12   29 2100-12-29
# 1120224        Long  NorESM2-MM      ssp585  2100     12   30 2100-12-30
# 1120225        Long  NorESM2-MM      ssp585  2100     12   31 2100-12-31
#
#          Spatial_Mean
# 0            4.782609
# 1            4.061304
# 2            5.264348
# 3            5.450870
# 4            6.903043
# ...               ...
# 1120221     13.868261
# 1120222     13.959565
# 1120223     15.040870
# 1120224     15.139565
# 1120225     15.122174
#
# [1120226 rows x 8 columns]

# %%
monthly_avg_df = spatial_mean_df.groupby(['time_span', 'model', 'projection', 'Year', 'Month'])['Spatial_Mean'].mean().reset_index()
monthly_avg_df
# Out:
#       time_span       model  projection  Year  Month  Spatial_Mean
# 0          Base  ACCESS-CM2  historical  1990      1      9.032440
# 1          Base  ACCESS-CM2  historical  1990      2      8.889472
# 2          Base  ACCESS-CM2  historical  1990      3     12.296592
# 3          Base  ACCESS-CM2  historical  1990      4     16.201058
# 4          Base  ACCESS-CM2  historical  1990      5     21.068738
# ...         ...         ...         ...   ...    ...           ...
# 36811     Short  NorESM2-MM      ssp585  2050      8     23.812496
# 36812     Short  NorESM2-MM      ssp585  2050      9     23.049246
# 36813     Short  NorESM2-MM      ssp585  2050     10     21.418008
# 36814     Short  NorESM2-MM      ssp585  2050     11     16.917783
# 36815     Short  NorESM2-MM      ssp585  2050     12     12.545554
#
# [36816 rows x 6 columns]

# %%
monthly_avg_df.rename({'Spatial_Mean' : 'Monthly_Mean'}, inplace = True, axis=1)

# %%
monthly_avg_df
# Out:
#       time_span       model  projection  Year  Month  Monthly_Mean
# 0          Base  ACCESS-CM2  historical  1990      1      9.032440
# 1          Base  ACCESS-CM2  historical  1990      2      8.889472
# 2          Base  ACCESS-CM2  historical  1990      3     12.296592
# 3          Base  ACCESS-CM2  historical  1990      4     16.201058
# 4          Base  ACCESS-CM2  historical  1990      5     21.068738
# ...         ...         ...         ...   ...    ...           ...
# 36811     Short  NorESM2-MM      ssp585  2050      8     23.812496
# 36812     Short  NorESM2-MM      ssp585  2050      9     23.049246
# 36813     Short  NorESM2-MM      ssp585  2050     10     21.418008
# 36814     Short  NorESM2-MM      ssp585  2050     11     16.917783
# 36815     Short  NorESM2-MM      ssp585  2050     12     12.545554
#
# [36816 rows x 6 columns]

# %%
selected_monthly_df = monthly_avg_df[monthly_avg_df['time_span']!= 'Historical']
selected_monthly_df
# Out:
#       time_span       model  projection  Year  Month  Monthly_Mean
# 0          Base  ACCESS-CM2  historical  1990      1      9.032440
# 1          Base  ACCESS-CM2  historical  1990      2      8.889472
# 2          Base  ACCESS-CM2  historical  1990      3     12.296592
# 3          Base  ACCESS-CM2  historical  1990      4     16.201058
# 4          Base  ACCESS-CM2  historical  1990      5     21.068738
# ...         ...         ...         ...   ...    ...           ...
# 36811     Short  NorESM2-MM      ssp585  2050      8     23.812496
# 36812     Short  NorESM2-MM      ssp585  2050      9     23.049246
# 36813     Short  NorESM2-MM      ssp585  2050     10     21.418008
# 36814     Short  NorESM2-MM      ssp585  2050     11     16.917783
# 36815     Short  NorESM2-MM      ssp585  2050     12     12.545554
#
# [27300 rows x 6 columns]

# %%
monthly_mean_df = selected_monthly_df.groupby(['time_span', 'projection', 'Month'])['Monthly_Mean'].mean().reset_index()
monthly_mean_df
# Out:
#    time_span  projection  Month  Monthly_Mean
# 0       Base  historical      1      8.216809
# 1       Base  historical      2      9.941944
# 2       Base  historical      3     13.657605
# 3       Base  historical      4     17.676367
# 4       Base  historical      5     20.379224
# ..       ...         ...    ...           ...
# 79     Short      ssp585      8     23.923663
# 80     Short      ssp585      9     22.632899
# 81     Short      ssp585     10     19.185994
# 82     Short      ssp585     11     15.128970
# 83     Short      ssp585     12     11.160159
#
# [84 rows x 4 columns]

# %%
model_base_df = monthly_mean_df[monthly_mean_df['projection'] == 'historical']
merged_monthly_mean_df = pd.merge(monthly_mean_df, model_base_df[['Month', 'Monthly_Mean']], on=['Month'], suffixes=('', '_base'))
change = (merged_monthly_mean_df['Monthly_Mean'] - merged_monthly_mean_df['Monthly_Mean_base'])
merged_monthly_mean_df['Change (°C)'] = change
merged_monthly_mean_df
# Out:
#    time_span  projection  Month  Monthly_Mean  Monthly_Mean_base  Change (°C)
# 0       Base  historical      1      8.216809           8.216809     0.000000
# 1       Base  historical      2      9.941944           9.941944     0.000000
# 2       Base  historical      3     13.657605          13.657605     0.000000
# 3       Base  historical      4     17.676367          17.676367     0.000000
# 4       Base  historical      5     20.379224          20.379224     0.000000
# ..       ...         ...    ...           ...                ...          ...
# 79     Short      ssp585      8     23.923663          22.639462     1.284202
# 80     Short      ssp585      9     22.632899          21.404276     1.228623
# 81     Short      ssp585     10     19.185994          18.194253     0.991741
# 82     Short      ssp585     11     15.128970          13.974878     1.154092
# 83     Short      ssp585     12     11.160159           9.840753     1.319406
#
# [84 rows x 6 columns]

# %%
merged_monthly_mean_df = merged_monthly_mean_df[merged_monthly_mean_df['Change (°C)'] != 0]
merged_monthly_mean_df
# Out:
#    time_span projection  Month  Monthly_Mean  Monthly_Mean_base  Change (°C)
# 12      Long     ssp245      1     11.136999           8.216809     2.920189
# 13      Long     ssp245      2     12.575696           9.941944     2.633751
# 14      Long     ssp245      3     16.023730          13.657605     2.366125
# 15      Long     ssp245      4     19.435266          17.676367     1.758899
# 16      Long     ssp245      5     21.852707          20.379224     1.473483
# ..       ...        ...    ...           ...                ...          ...
# 79     Short     ssp585      8     23.923663          22.639462     1.284202
# 80     Short     ssp585      9     22.632899          21.404276     1.228623
# 81     Short     ssp585     10     19.185994          18.194253     0.991741
# 82     Short     ssp585     11     15.128970          13.974878     1.154092
# 83     Short     ssp585     12     11.160159           9.840753     1.319406
#
# [72 rows x 6 columns]

# %%
# merged_monthly_mean_df.to_csv(f'G:\MJI\SKZ\Script\From RAJ\Output\Analysis\Tmin_Change.csv')

# %%
for scenario in set(merged_monthly_mean_df['projection']):
    scenario_df = merged_monthly_mean_df[merged_monthly_mean_df['projection'] == scenario]

# %%
selected_scenario_df = scenario_df[['time_span', 'Month', 'Change (°C)']]
selected_scenario_df
# Out:
#    time_span  Month  Change (°C)
# 12      Long      1     2.920189
# 13      Long      2     2.633751
# 14      Long      3     2.366125
# 15      Long      4     1.758899
# 16      Long      5     1.473483
# 17      Long      6     1.977533
# 18      Long      7     2.221618
# 19      Long      8     2.237586
# 20      Long      9     2.172527
# 21      Long     10     1.730563
# 22      Long     11     2.197442
# 23      Long     12     2.784472
# 36       Mid      1     2.246224
# 37       Mid      2     2.182352
# 38       Mid      3     1.914883
# 39       Mid      4     1.403817
# 40       Mid      5     1.158304
# 41       Mid      6     1.556002
# 42       Mid      7     1.785318
# 43       Mid      8     1.759663
# 44       Mid      9     1.668331
# 45       Mid     10     1.396717
# 46       Mid     11     1.786084
# 47       Mid     12     2.206892
# 60     Short      1     1.281482
# 61     Short      2     1.225752
# 62     Short      3     1.111216
# 63     Short      4     0.804248
# 64     Short      5     0.660803
# 65     Short      6     0.837250
# 66     Short      7     1.014826
# 67     Short      8     1.058788
# 68     Short      9     1.021606
# 69     Short     10     0.772283
# 70     Short     11     1.023479
# 71     Short     12     1.166762

# %%
heatmap_df = selected_scenario_df.pivot(index='time_span', columns='Month', values='Change (°C)')
heatmap_df.sort_index(ascending=False, inplace=True)
heatmap_df
# Out:
# Month            1         2         3         4         5         6   \
# time_span
# Short      1.281482  1.225752  1.111216  0.804248  0.660803  0.837250
# Mid        2.246224  2.182352  1.914883  1.403817  1.158304  1.556002
# Long       2.920189  2.633751  2.366125  1.758899  1.473483  1.977533
#
# Month            7         8         9         10        11        12
# time_span
# Short      1.014826  1.058788  1.021606  0.772283  1.023479  1.166762
# Mid        1.785318  1.759663  1.668331  1.396717  1.786084  2.206892
# Long       2.221618  2.237586  2.172527  1.730563  2.197442  2.784472

# %%
fig, ax = plt.subplots(1,1,figsize=(10,5))
font = {'family' : 'Times New Roman',              
        'weight' : 'normal',
        'size'   : 10}

plt.rc('font',**font)
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=10)

sns.heatmap(data=heatmap_df, vmin=None, vmax=None, annot=True, fmt='.2f',  cmap='Reds', square=True,
            cbar_kws={'label': 'Change in Montly Change (°C)','orientation': 'horizontal'}, 
            linewidths=0.5, linecolor='black',ax=ax)
# annot_kws={'color': 'black'}

xtick_positions = ax.get_xticks()
xtick_labels_list = [calendar.month_name[int(label.get_text())][:3] for label in ax.get_xticklabels()]
ax.set_xticks(xtick_positions)
ax.set_xticklabels(xtick_labels_list)
ax.xaxis.tick_top()
ax.tick_params(axis='x', which='both', length=0)
ax.tick_params(axis='y', which='both', length=0)

# Adjust colorbar position and width
cbar = ax.collections[0].colorbar  # Get the colorbar
cbar.set_label('Change in Monthly Change (°C)')

# Change colorbar position
cbar.ax.set_position([0.125, -0.5, 0.775, 0.8])  # [left, bottom, width, height]

ax.xaxis.set_label_position('top') 
ax.set_xlabel('Month', fontsize=12, fontweight='bold')
ax.set_ylabel('Timespan',  fontsize=12, fontweight='bold')
ax.set_title(f'Monthly Chnage in Maximum Temperature ({scenario.upper()})', fontsize=14, fontweight='bold', x=0.5, y = 1.2)
# plt.tight_layout()
# Out:
# Text(0.5, 1.2, 'Monthly Chnage in Maximum Temperature (SSP245)')

# %%
# Colormap for temperature changes
cmap_temp = plt.get_cmap("Reds")  

fig, ax = plt.subplots(1,1,figsize=(8,4), dpi=300)
font = {'family' : 'Times New Roman',              
        'weight' : 'normal',
        'size'   : 10}

plt.rc('font',**font)
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=10)

sns.heatmap(data=heatmap_df, vmin=None, vmax=None, annot=True, fmt='.2f',  cmap='Reds', square=True,
            cbar=False, linewidths=0.1, linecolor='black', ax=ax, annot_kws={'color': 'black'})

# Customize x-tick labels (months)
xtick_positions = ax.get_xticks()
xtick_labels_list = [calendar.month_name[int(label.get_text())][:3] for label in ax.get_xticklabels()]
ax.set_xticks(xtick_positions)
ax.set_xticklabels(xtick_labels_list)

# Customize the y-tick labels (timespan)
timespan_labels = ['Near\n(2026-2050)', 'Mid\n(2051-2075)', 'Long\n(2076-2100)']
ax.set_yticks(np.arange(len(timespan_labels)) + 0.5) 
ax.set_yticklabels(timespan_labels, fontsize=10, rotation=0, ha='center', va='center')
ax.tick_params(axis='y', which='major', pad=27)

# Move x-axis to top
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
ax.yaxis.set_label_position('left')

# Hide tick lines
ax.tick_params(axis='x', which='both', length=0)
ax.tick_params(axis='y', which='both', length=0)

# Show ticks on top and left
ax.tick_params(top=True, bottom=False, left=True, right=False)
ax.xaxis.set_ticks_position('top')
ax.yaxis.set_ticks_position('left')

# Adding the colorbar
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="10%", pad=0.1)  # 5% height, 0.1 pad
sm_precip = plt.cm.ScalarMappable(cmap=cmap_temp, norm=plt.Normalize(vmin=1, vmax=5))
cbar = plt.colorbar(sm_precip, cax=cax, orientation='horizontal', extend='both')
cbar.set_label('Change in Minimum Tempearture (°C)', fontsize=10)

ax.xaxis.set_label_position('top') 
ax.set_xlabel('Month', fontsize=12, fontweight='bold')
ax.set_ylabel('Timespan',  fontsize=12, fontweight='bold')
ax.set_title(f'Monthly Change in Minimum Temperature ({scenario.upper()})', fontsize=12, 
             fontweight='bold', x=0.5, y = 1.25)

plt.savefig(r'D:\Script\From_RAJ\Output\Tmin_SSP245_Heatmap.jpg',
            dpi=600, bbox_inches = 'tight')
